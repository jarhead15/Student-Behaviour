# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("Student_Behaviour.csv")

# %%
data
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %%
data.head()
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
# 2    Male        BCA       159.0        78.0       69.5       61.0
# 3  Female        BCA       147.0        20.0       70.0       59.0
# 4    Male        BCA       170.0        54.0       40.0       65.0
#
#    college mark        hobbies daily studing time prefer to study in  \
# 0          80.0    Video Games      0 - 30 minute            Morning
# ...

# %%
data.shape
# Out:
# (235, 19)

# %%
data.columns
# Out:
# Index(['Have you completed any certification courses, or are you currently enrolled in any?',
#        'Gender', 'Department', 'Height(CM)', 'Weight(KG)', '10th Mark',
#        '12th Mark', 'college mark', 'hobbies', 'daily studing time',
#        'prefer to study in', 'salary expectation', 'Do you like your degree?',
#        'possibility of choosing  their career based on their degree : ',
#        'social medai & video games spending Time', 'Travelling Time ',
#        'Stress Level ', 'Financial Status',
#        'Are you doing a part-time job right now?'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=235, step=1)

# %%
data.dtypes
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?     object
# Gender                                                                                  object
# Department                                                                              object
# Height(CM)                                                                             float64
# Weight(KG)                                                                             float64
# 10th Mark                                                                              float64
# 12th Mark                                                                              float64
# college mark                                                                           float64
# hobbies                                                                                 object
# daily studing time                                                                      object
# ...

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data["hobbies"].unique()
# Out:
# array(['Video Games', 'Cinema', 'Reading books', 'Sports'], dtype=object)

# %%
data.nunique()
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?     2
# Gender                                                                                  2
# Department                                                                              4
# Height(CM)                                                                             56
# Weight(KG)                                                                             52
# 10th Mark                                                                              68
# 12th Mark                                                                              67
# college mark                                                                           43
# hobbies                                                                                 4
# daily studing time                                                                      6
# ...

# %%
data.count()
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?    235
# Gender                                                                                 235
# Department                                                                             235
# Height(CM)                                                                             235
# Weight(KG)                                                                             235
# 10th Mark                                                                              235
# 12th Mark                                                                              235
# college mark                                                                           235
# hobbies                                                                                235
# daily studing time                                                                     235
# ...

# %%
data.value_counts()
# Out:
# Have you completed any certification courses, or are you currently enrolled in any?  Gender  Department                     Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  hobbies        daily studing time  prefer to study in  salary expectation  Do you like your degree?  possibility of choosing  their career based on their degree :   social medai & video games spending Time  Travelling Time   Stress Level   Financial Status  Are you doing a part-time job right now?
# No                                                                                   Female  B.com Accounting and Finance   130.0       35.0        80.2       70.0       12.0          Reading books  More Than 4 hour    Morning             30000               No                        50%                                                             30 - 60 Minute                            1 - 1.30 hour     Good           Bad               No                                          1
# ...

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %%
data.Gender.value_counts()
# Out:
# Male      156
# Female     79
# Name: Gender, dtype: int64

# %%
data.Gender == "Male"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 230     True
# 231     True
# 232    False
# 233    False
# 234    False
# Name: Gender, Length: 235, dtype: bool

# %%
data[data.Gender == "Male"]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 2                                                  Yes
# 4                                                   No
# 6                                                  Yes
# 7                                                   No
# ..                                                 ...
# 223                                                Yes
# 227                                                Yes
# 228                                                Yes
# 230                                                Yes
# 231                                                Yes
#
#     Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0     Male        BCA       100.0        58.0       79.0      65.00
# 2     Male        BCA       159.0        78.0       69.5      61.00
# ...

# %%
data.Department.value_counts()
# Out:
# BCA                              132
# Commerce                          60
# B.com ISM                         28
# B.com Accounting and Finance      15
# Name: Department, dtype: int64

# %% [markdown]
# Only BCA students

# %%
data.Department =="BCA"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 230    False
# 231    False
# 232     True
# 233    False
# 234    False
# Name: Department, Length: 235, dtype: bool

# %%
data[data.Department == "BCA"]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 154                                                Yes
# 155                                                Yes
# 156                                                Yes
# 157                                                Yes
# 232                                                Yes
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %% [markdown]
# Height More than 150

# %%
data["Height(CM)"].value_counts()
# Out:
# 160.0    23
# 170.0    20
# 150.0    15
# 155.0    12
# 175.0    11
# 165.0    10
# 153.0    10
# 156.0     9
# 180.0     8
# 152.0     7
# 167.0     7
# 172.0     6
# 154.0     5
# 159.0     5
# 162.0     5
# 157.0     4
# 173.0     4
# 100.0     4
# 190.0     4
# 149.0     3
# 158.0     3
# 120.0     3
# 151.0     3
# 145.0     3
# 163.0     3
# 99.0      3
# 90.0      3
# 139.0     3
# 177.0     3
# 140.0     2
# 182.0     2
# 178.0     2
# 174.0     2
# 146.0     2
# 161.0     2
# 168.0     2
# 185.0     2
# 169.0     2
# 192.0     1
# 130.0     1
# 148.0     1
# 134.0     1
# 98.0      1
# 132.0     1
# 187.0     1
# 179.0     1
# 181.0     1
# 183.0     1
# 4.5       1
# 171.0     1
# 106.0     1
# 144.0     1
# 142.0     1
# 109.0     1
# 147.0     1
# 164.0     1
# Name: Height(CM), dtype: int64

# %%
data["Height(CM)"] > 150
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 230     True
# 231     True
# 232    False
# 233     True
# 234     True
# Name: Height(CM), Length: 235, dtype: bool

# %%
data[data["Height(CM)"] > 150]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 2                                                  Yes
# 4                                                   No
# 6                                                  Yes
# 7                                                   No
# 8                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                Yes
# 231                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 2      Male        BCA       159.0        78.0       69.5      61.00
# 4      Male        BCA       170.0        54.0       40.0      65.00
# ...

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %% [markdown]
# No of students like the degree

# %%
data["Do you like your degree?"].value_counts()
# Out:
# Yes    215
# No      20
# Name: Do you like your degree?, dtype: int64

# %%
data[data["Do you like your degree?"] == "Yes"]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 1                                                   No
# 2                                                  Yes
# 4                                                   No
# 5                                                  Yes
# 6                                                  Yes
# ..                                                 ...
# 229                                                 No
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 1    Female        BCA        90.0        40.0       70.0       80.0
# 2      Male        BCA       159.0        78.0       69.5       61.0
# ...

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %% [markdown]
# Get the data of the best students

# %%
#for the best students we are considering the overall mean marks above 75 of 10th, 12th and college marks

# %%
data["mean marks"] = data.loc[:, ["10th Mark","12th Mark","college mark"]].mean(axis = 1)

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time  ... salary expectation  \
# 0          80.0  Video Games      0 - 30 minute  ...              40000
# 1          70.0       Cinema     30 - 60 minute  ...              15000
#
#    Do you like your degree?  \
# 0                        No
# 1                       Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
#   social medai & video games spending Time Travelling Time  Stress Level   \
# ...

# %%
data["mean marks"] > 75
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 230    False
# 231    False
# 232     True
# 233     True
# 234    False
# Name: mean marks, Length: 235, dtype: bool

# %%
data[data["mean marks"] > 75]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 5                                                  Yes
# 14                                                 Yes
# 16                                                 Yes
# 26                                                 Yes
# 28                                                  No
# ..                                                 ...
# 224                                                Yes
# 225                                                Yes
# 226                                                Yes
# 232                                                Yes
# 233                                                Yes
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 5    Female        BCA       139.0        33.0       90.0       75.0
# 14     Male        BCA       160.0        83.0       89.5       69.7
# ...

# %% [markdown]
# No of students who are above 75 marks and are female

# %%
data[(data["mean marks"] > 75) & (data.Gender == "Female")]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 5                                                  Yes
# 28                                                  No
# 29                                                  No
# 36                                                  No
# 37                                                  No
# 42                                                  No
# 51                                                 Yes
# 53                                                 Yes
# 54                                                 Yes
# 56                                                 Yes
# 58                                                 Yes
# 60                                                 Yes
# 61                                                 Yes
# 66                                                 Yes
# 72                                                  No
# ...

# %%
data[(data["mean marks"] > 75) & (data.Gender == "Female")].shape
# Out:
# (46, 21)

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time  ... salary expectation  \
# 0          80.0  Video Games      0 - 30 minute  ...              40000
# 1          70.0       Cinema     30 - 60 minute  ...              15000
#
#    Do you like your degree?  \
# 0                        No
# 1                       Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
#   social medai & video games spending Time Travelling Time  Stress Level   \
# ...

# %%
data. drop("mean", axis=1, inplace=True)

# %%
data.head(2)
# Out:
#   Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                 No
# 1                                                 No
#
#    Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0    Male        BCA       100.0        58.0       79.0       65.0
# 1  Female        BCA        90.0        40.0       70.0       80.0
#
#    college mark      hobbies daily studing time prefer to study in  \
# 0          80.0  Video Games      0 - 30 minute            Morning
# 1          70.0       Cinema     30 - 60 minute            Morning
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
#
#   possibility of choosing  their career based on their degree :   \
# 0                                                50%
# 1                                                75%
#
# ...

# %% [markdown]
# Point out the students who prefers study in the morning, is male, and do like the degree

# %%
data[(data["prefer to study in"] == "Morning") & (data.Gender == "Male") & (data["Do you like your degree?"] == "Yes")]
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 4                                                   No
# 6                                                  Yes
# 7                                                   No
# 8                                                   No
# 10                                                  No
# 21                                                  No
# 23                                                  No
# 25                                                  No
# 27                                                  No
# 30                                                  No
# 35                                                  No
# 38                                                 Yes
# 48                                                 Yes
# 50                                                 Yes
# 55                                                  No
# ...

# %%
data[(data["prefer to study in"] == "Morning") & (data.Gender == "Male") & (data["Do you like your degree?"] == "Yes")].shape
# Out:
# (49, 20)

# %%
data.groupby("Gender").max()
# Out:
#        Have you completed any certification courses, or are you currently enrolled in any?  \
# Gender
# Female                                                Yes
# Male                                                  Yes
#
#        Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  \
# Gender
# Female   Commerce       180.0        95.0       98.0       94.0         100.0
# Male     Commerce       192.0       106.0       95.0       91.0          97.0
#
#             hobbies daily studing time prefer to study in  salary expectation  \
# Gender
# Female  Video Games   More Than 4 hour              Night             1500000
# Male    Video Games   More Than 4 hour              Night              700000
#
#        Do you like your degree?  \
# Gender
# Female                      Yes
# Male                        Yes
#
#        possibility of choosing  their career based on their degree :   \
# Gender
# Female                                                75%
# ...

# %%
data.groupby("Gender").min()
# Out:
#        Have you completed any certification courses, or are you currently enrolled in any?  \
# Gender
# Female                                                 No
# Male                                                   No
#
#                            Department  Height(CM)  Weight(KG)  10th Mark  \
# Gender
# Female  B.com Accounting and Finance          4.5        20.0        7.4
# Male    B.com Accounting and Finance         90.0        35.0       40.0
#
#         12th Mark  college mark hobbies daily studing time prefer to study in  \
# Gender
# Female       45.0          12.0  Cinema      0 - 30 minute            Anytime
# Male         47.0           1.0  Cinema      0 - 30 minute            Anytime
#
#         salary expectation Do you like your degree?  \
# Gender
# Female                  10                       No
# Male                     0                       No
#
#        possibility of choosing  their career based on their degree :   \
# Gender
# ...

# %%
data.groupby("Department").std()   #Standard Deviation
# Out:
#                                Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# Department
# B.com Accounting and Finance    20.762145   15.421074   9.416965  10.110932
# B.com ISM                       12.527641   15.203209  11.146630  11.153273
# BCA                             25.346868   14.840212  13.040837   9.637240
# Commerce                        14.567629   15.049176  10.448158   9.554588
#
#                                college mark  salary expectation  mean marks
# Department
# B.com Accounting and Finance      26.579978        31353.286453   11.750302
# B.com ISM                         16.240911       155178.795049   10.346439
# BCA                               13.672101       129240.389464    9.114865
# Commerce                          12.412634        15152.111036    9.305305
